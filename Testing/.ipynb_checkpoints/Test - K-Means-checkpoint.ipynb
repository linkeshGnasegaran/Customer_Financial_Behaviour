# %% [markdown]
# ## K-Means Clustering

# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans

# %% [markdown]
# ### Import dataset

# %%
df = pd.read_csv("cleaned_customer_financial_behaviour.csv")

# %% [markdown]
# ### Select Features

# %%
features = [
    "annual_income",
    "monthly_income",
    "loan_amount",
    "credit_score_origination",
    "dti",
    "revolving_utilization_origination"
]

X = df[features]

# %% [markdown]
# ### Standardise the data

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %% [markdown]
# ### Elbow Mthode

# %%
sse = []
for k in range(2, 9):
    model = KMeans(
        n_clusters=k,
        random_state=42,
        n_init=10
    )
    model.fit(X_scaled)
    sse.append(model.inertia_)

# %% [markdown]
# ### Plot Elbow

# %%
plt.figure(figsize=(8,5))
plt.plot(
    range(2,9),
    sse,
    marker="o"
)
plt.title("Elbow Method")
plt.xlabel("Number of Clusters (K)")
plt.ylabel("Sum of Squared Errors (SSE)")
plt.show()

# %% [markdown]
# ### Train K-Means

# %%
kmeans = KMeans(
    n_clusters=3,
    random_state=42,
    n_init=10
)
df["cluster"] = kmeans.fit_predict(X_scaled)

# %% [markdown]
# ### View Cluster Count

# %%
print(df["cluster"].value_counts())
# Out:
# cluster
# 2    74824
# 1    46316
# 0    13860
# Name: count, dtype: int64

# %% [markdown]
# ### Cluster Profile

# %%
cluster_profile = df.groupby("cluster")[features].mean()
print(cluster_profile)
# Out:
#          annual_income  monthly_income   loan_amount  \
# cluster
# 0        288699.173160    24058.264426  81500.105700
# 1        110018.905735     9168.242144  50755.847698
# 2        107404.974340     8950.414509  50638.840185
#
#          credit_score_origination       dti  revolving_utilization_origination
# cluster
# 0                      689.996248  0.311014                           0.277736
# 1                      690.273383  0.307198                           0.454027
# 2                      689.957901  0.314450                           0.182052

# %% [markdown]
# ### Scatter Plot

# %%
plt.figure(figsize=(8,6))
plt.scatter(
    df["annual_income"],
    df["loan_amount"],
    c=df["cluster"]
)
plt.xlabel("Annual Income")
plt.ylabel("Loan Amount")
plt.title("Customer Segmentation using K-Means")
plt.show()
